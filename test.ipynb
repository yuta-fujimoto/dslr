# %%
import pandas as pd


s = pd.Series([1, 2, 3, 4])
s.describe()
# Out:
# count    4.000000
# mean     2.500000
# std      1.290994
# min      1.000000
# 25%      1.750000
# 50%      2.500000
# 75%      3.250000
# max      4.000000
# dtype: float64

# %%
# Out:
#              Arithmancy      Astronomy  Herbology  \
# Count              1566           1568       1567
# Mean       49634.570243      39.797131    1.14102
# Std    278038269.148003  270537.640406  27.227693
# Min             58384.0    -487.886086    5.72718
# 25%            66702.75     244.016938   1.363448
# 50%             38621.5     -69.499227  -1.825474
# 75%             52069.5    -159.461642   4.550629
# Max             35883.0    -604.360936  -6.016943
#
#       Defense Against the Dark Arts Divination Muggle Studies Ancient Runes  \
# Count                          1569       1561           1565          1565
# Mean                      -0.387863    3.15391    -224.589915     495.74797
# Std                       27.155899  17.255464  236380.164843  11289.317975
# Min                        4.878861      4.722     272.035831    532.484226
# 25%                        -4.72009      5.561    -573.705363    398.553185
# ...
